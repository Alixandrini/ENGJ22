# %% [markdown]
# # Lista de Exercícios: Ajustamento pelo Método Correlato
# **Professor:** Mauro
# **Disciplina:** Ajustamento de Observações Geodésicas

# %% [markdown]
# ## Exercício 1: Circuito Quadrangular Simples
# Determine os desníveis ajustados para a rede abaixo, onde o ponto A é fixo.
#
# **Dados de Observação:**
# 1. $L_1 (A \rightarrow B): \Delta H = 10.050$ m, $s = 2$ km
# 2. $L_2 (B \rightarrow C): \Delta H = 5.120$ m, $s = 1$ km
# 3. $L_3 (C \rightarrow D): \Delta H = -10.080$ m, $s = 2$ km
# 4. $L_4 (D \rightarrow A): \Delta H = -5.100$ m, $s = 1$ km
#
# **Dica:** Há apenas 1 equação de condição (fechamento do polígono).

# %%
# Implemente a resolução do Exercício 1 aqui
import numpy as np

Lb1 = np.array([[10.050], [5.120], [-10.080], [-5.100]])
P1 = np.diag([1/2, 1/1, 1/2, 1/1])
B1 = np.array([[1, 1, 1, 1]]) # L1+L2+L3+L4 = 0

# Siga com o cálculo de K e V...

# %% [markdown]
# ## Exercício 2: Rede com Ponto Central
# Ajuste a rede onde três pontos (1, 2, 3) são conectados a um ponto central (P). Os pontos 1, 2 e 3 possuem altitudes conhecidas (Fixos).
#
#
# **Dados de Observação:**
# 1. $L_1 (1 \rightarrow P): \Delta H = 2.450$ m, $s = 3$ km
# 2. $L_2 (2 \rightarrow P): \Delta H = -1.560$ m, $s = 2$ km
# 3. $L_3 (3 \rightarrow P): \Delta H = 4.880$ m, $s = 4$ km
#
# **Altitudes Fixas:**
# - $H_1 = 100.000$ m
# - $H_2 = 104.015$ m
# - $H_3 = 97.575$ m
#
# **Dica:** Crie condições relacionando os desníveis com as altitudes fixas conhecidas.

# %%
# Implemente a resolução do Exercício 2 aqui

# %% [markdown]
# ## Exercício 3: Rede de Nivelamento Complexa (Triângulos Adjacentes)
# Com base na imagem do Exercício 3 fornecida em aula, ajuste os 6 desníveis que conectam os pontos A, B, C e D.
#
# **Dados de Observação:**
# | Linha | De | Para | ΔH (m) | Dist (km) |
# |:---:|:---:|:---:|:---:|:---:|
# | L1 | A | B | 5.432 | 2.5 |
# | L2 | B | C | 3.210 | 1.8 |
# | L3 | C | A | -8.645 | 3.0 |
# | L4 | B | D | 2.150 | 2.0 |
# | L5 | D | C | 1.065 | 1.5 |
# | L6 | A | D | 7.580 | 4.0 |
#
# **Tarefa:** Identifique os circuitos independentes e realize o ajustamento correlato.

# %%
# Implemente a resolução do Exercício 3 aqui
